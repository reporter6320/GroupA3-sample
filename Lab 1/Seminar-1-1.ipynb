# %%
data <- read.csv("Data_T1.csv")

# %%
# a first look at the data
head(data)
summary(data)
# Out:
#   X ID GROUP NFL   PTAU181
# 1 1 1  0     37.65 1.45
# 2 2 2  0     12.96 1.30
# 3 3 3  0     25.75 1.04
# 4 4 4  0     15.01 1.13
# 5 5 5  0     22.28 2.03
# 6 6 6  0      8.12 0.61
#        X               ID            GROUP          NFL           PTAU181
#  Min.   : 1.00   Min.   : 1.00   Min.   :0.0   Min.   : 6.96   Min.   :0.6100
#  1st Qu.:10.75   1st Qu.: 5.75   1st Qu.:0.0   1st Qu.:14.85   1st Qu.:0.9225
#  Median :20.50   Median :10.50   Median :0.5   Median :21.31   Median :1.4500
#  Mean   :20.50   Mean   :10.50   Mean   :0.5   Mean   :25.88   Mean   :1.5742
#  3rd Qu.:30.25   3rd Qu.:15.25   3rd Qu.:1.0   3rd Qu.:32.21   3rd Qu.:2.0350
#  Max.   :40.00   Max.   :20.00   Max.   :1.0   Max.   :72.83   Max.   :4.7000

# %%
dim(data)
# Out:
# [1] 40  5

# %%
library(ggplot2)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# Create a data frame for plotting (assuming 'data' is the name of your data frame)
df_plot <- data %>%
  select(GROUP, NFL, PTAU181) %>%
  mutate(
    GROUP = factor(GROUP),
    NFL_label = case_when(
      GROUP == 0 ~ "GROUP 0",
      GROUP == 1 ~ "GROUP 1"
    ),
    PTAU181_label = case_when(
      GROUP == 0 ~ "GROUP 0",
      GROUP == 1 ~ "GROUP 1"
    )
  )

# %%
# Histograms for NFL and PTAU181
p_NFL <- ggplot(df_plot, aes(x = NFL, fill = NFL_label)) +
  geom_histogram(binwidth = 5, color = "black", alpha = 0.7) +
  labs(title = "Histogram of NfL concentrations", x = "NfL (pg/mL)", y = "Count") +
  theme_classic()

# %%
p_PTAU181 <- ggplot(df_plot, aes(x = PTAU181, fill = PTAU181_label)) +
  geom_histogram(binwidth = 0.1, color = "black", alpha = 0.7) +
  labs(title = "Histogram of p-tau181 concentrations", x = "p-tau181 (pg/mL)", y = "Count") +
  theme_classic()

# %%
# Scatter plots for NFL vs PTAU181 within each group
p_NFL_PTAU181 <- ggplot(df_plot, aes(x = PTAU181, y = NFL)) +
  geom_point(aes(color = NFL_label), size = 2) +
  labs(title = "Scatter plot of NfL vs p-tau181", x = "p-tau181 (pg/mL)", y = "NfL (pg/mL)") +
  theme_classic()

# %%
# Display plots
print(p_NFL)
print(p_PTAU181)
print(p_NFL_PTAU181)
# Out:
# plot without title
# plot without title
# plot without title

# %%
ggplot(df_plot, aes(x = NFL_label)) +
  geom_boxplot(aes(y = NFL), color = "black", fill = "lightblue") +
  labs(title = "Boxplot of NfL concentrations by group", x = "Group", y = "NfL (pg/mL)") +
  theme_classic()

ggplot(df_plot, aes(x = PTAU181_label)) +
  geom_boxplot(aes(y = PTAU181), color = "black", fill = "lightblue") +
  labs(title = "Boxplot of p-tau181 concentrations by group", x = "Group", y = "p-tau181 (pg/mL)") +
  theme_classic()
# Out:
# plot without title
# plot without title

# %%
df_plot
# Out:
#    GROUP NFL   PTAU181 NFL_label PTAU181_label
# 1  0     37.65 1.45    GROUP 0   GROUP 0
# 2  0     12.96 1.30    GROUP 0   GROUP 0
# 3  0     25.75 1.04    GROUP 0   GROUP 0
# 4  0     15.01 1.13    GROUP 0   GROUP 0
# 5  0     22.28 2.03    GROUP 0   GROUP 0
# 6  0      8.12 0.61    GROUP 0   GROUP 0
# 7  0     14.38 0.90    GROUP 0   GROUP 0
# 8  0     23.01 1.60    GROUP 0   GROUP 0
# 9  0      7.60 1.56    GROUP 0   GROUP 0
# 10 0     13.63 0.83    GROUP 0   GROUP 0
# 11 0     17.14 2.75    GROUP 0   GROUP 0
# 12 0      8.13 2.55    GROUP 0   GROUP 0
# 13 0      6.96 0.84    GROUP 0   GROUP 0
# 14 0     15.73 0.62    GROUP 0   GROUP 0
# 15 0     20.33 1.56    GROUP 0   GROUP 0
# 16 0     21.86 1.92    GROUP 0   GROUP 0
# 17 0     20.81 0.61    GROUP 0   GROUP 0
# 18 0     21.42 0.85    GROUP 0   GROUP 0
# 19 0     32.27 2.22    GROUP 0   GROUP 0
# 20 0     14.20 1.18    GROUP 0   GROUP 0
# 21 1     49.94 0.81    GROUP 1   GROUP 1
# 22 1     21.20 2.66    GROUP 1   GROUP 1
# 23 1     51.24 1.82    GROUP 1   GROUP 1
# 24 1     31.27 2.08    GROUP 1   GROUP 1
# 25 1     19.60 1.45    GROUP 1   GROUP 1
# 26 1     44.39 1.45    GROUP 1   GROUP 1
# 27 1     18.19 3.45    GROUP 1   GROUP 1
# 28 1     16.69 2.45    GROUP 1   GROUP 1
# 29 1     50.43 0.73    GROUP 1   GROUP 1
# 30 1     19.05 2.22    GROUP 1   GROUP 1
# 31 1     23.56 0.82    GROUP 1   GROUP 1
# 32 1     42.68 1.11    GROUP 1   GROUP 1
# 33 1     31.15 2.05    GROUP 1   GROUP 1
# 34 1     32.97 1.47    GROUP 1   GROUP 1
# 35 1     12.46 1.16    GROUP 1   GROUP 1
# 36 1     10.89 4.70    GROUP 1   GROUP 1
# 37 1     32.19 1.23    GROUP 1   GROUP 1
# 38 1     63.03 1.86    GROUP 1   GROUP 1
# 39 1     72.83 0.97    GROUP 1   GROUP 1
# 40 1     32.01 0.93    GROUP 1   GROUP 1

# %%
# Perform Shapiro-Wilk normality test for NFL concentrations
shapiro_test_NFL_1 <- shapiro.test(df_plot[df_plot$GROUP == 1, ]$NFL) 


print(shapiro_test_NFL_1)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  df_plot[df_plot$GROUP == 1, ]$NFL
# W = 0.93541, p-value = 0.1961

# %%
# Perform Shapiro-Wilk normality test for NFL concentrations
shapiro_test_NFL_0 <- shapiro.test(df_plot[df_plot$GROUP == 0, ]$NFL) 


print(shapiro_test_NFL_0)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  df_plot[df_plot$GROUP == 0, ]$NFL
# W = 0.93826, p-value = 0.2222

# %%
# Perform Shapiro-Wilk normality test for NFL concentrations
shapiro_test_PTAU181_0 <- shapiro.test(df_plot[df_plot$GROUP == 0, ]$PTAU181) 


print(shapiro_test_PTAU181_0)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  df_plot[df_plot$GROUP == 0, ]$PTAU181
# W = 0.924, p-value = 0.1183

# %%
# Perform Shapiro-Wilk normality test for NFL concentrations
shapiro_test_PTAU181_1 <- shapiro.test(df_plot[df_plot$GROUP == 1, ]$PTAU181) 


print(shapiro_test_PTAU181_1)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  df_plot[df_plot$GROUP == 1, ]$PTAU181
# W = 0.85896, p-value = 0.00756

# %%
# Perform a two-sample t-test
t_test_result <- t.test(df_plot[df_plot$GROUP == 0, ]$NFL, df_plot[df_plot$GROUP == 1, ]$NFL)

# Print the results
print(t_test_result)
# Out:
# 	Welch Two Sample t-test
#
# data:  df_plot[df_plot$GROUP == 0, ]$NFL and df_plot[df_plot$GROUP == 1, ]$NFL
# t = -3.721, df = 27.013, p-value = 0.0009209
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -24.553374  -7.099626
# sample estimates:
# mean of x mean of y
#   17.9620   33.7885

# %%
log_PTAU181_1 <- log(df_plot[df_plot$GROUP == 1, ]$PTAU181)

# %%
shapiro.test(log_PTAU181_1)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  log_PTAU181_1
# W = 0.97003, p-value = 0.7555

# %%
# Perform a two-sample t-test
t_test_result_PTAU181 <- t.test(df_plot[df_plot$GROUP == 0, ]$PTAU181, log_PTAU181_1)

# Print the results
print(t_test_result_PTAU181)
# Out:
# 	Welch Two Sample t-test
#
# data:  df_plot[df_plot$GROUP == 0, ]$PTAU181 and log_PTAU181_1
# t = 5.0967, df = 35.98, p-value = 1.119e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.5617709 1.3043541
# sample estimates:
# mean of x mean of y
# 1.3775000 0.4444375
