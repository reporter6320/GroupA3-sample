# %%
library(devtools)
library(CM2018rpackage)
library(usethis)
# Out:
# Loading required package: usethis

# %%
# loading "a_clinical_dataset":
data <- a_clinical_dataset()

# %%
plot(data)
# Out:
# plot without title

# %%
# a first look at the data
head(data)
summary(data)
# Out:
# [1] 0.8289207 0.6311663 1.3940886 3.4204832 1.7250716 5.9302008
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.3842  0.7256  1.2067  1.8139  2.0171  5.9302
